# %%
import pandas as pd
import numpy as np
retail_sales_database_data = pd.read_csv(r"C:\Users\sigan\3D Objects\My Projects\Project\retail_sales_dataset.csv")
import warnings
warnings.filterwarnings("ignore")

import os
# %matplotlib inline

np.random.seed(0)

# %%
retail_sales_database_data.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df_data.shape
# Out:
# (1000, 8)

# %%
df_data.count()
# Out:
# Transaction ID      1000
# Customer ID         1000
# Gender              1000
# Age                 1000
# Product Category    1000
# Quantity            1000
# Price per Unit      1000
# Total Amount        1000
# dtype: int64

# %%
df.dropna()
# Out:
#            Customer ID  Gender  Age Product Category  Quantity  \
# Date
# 2023-02-27     CUST002  Female   26         Clothing         2
# 2023-01-13     CUST003    Male   50      Electronics         1
# ...                ...     ...  ...              ...       ...
# 2023-12-05     CUST999  Female   36      Electronics         3
# 2023-04-12    CUST1000    Male   47      Electronics         4
#
#             Price per Unit  Total Amount  Time   Lag_1
# Date
# 2023-02-27             500          1000     1   150.0
# 2023-01-13              30            30     2  1000.0
# ...                    ...           ...   ...     ...
# 2023-12-05              50           150   998   100.0
# 2023-04-12              30           120   999   150.0
#
# [999 rows x 9 columns]

# %%
import pandas as pd
df = pd.read_csv(
    r"C:\Users\sigan\3D Objects\My Projects\Project\retail_sales_dataset.csv",
    index_col='Date',
    parse_dates=['Date'],
).drop('Transaction ID', axis=1)
df.head()
# Out:
#            Customer ID  Gender  Age Product Category  Quantity  \
# Date
# 2023-11-24     CUST001    Male   34           Beauty         3
# 2023-02-27     CUST002  Female   26         Clothing         2
# 2023-01-13     CUST003    Male   50      Electronics         1
# 2023-05-21     CUST004    Male   37         Clothing         1
# 2023-05-06     CUST005    Male   30           Beauty         2
#
#             Price per Unit  Total Amount
# Date
# 2023-11-24              50           150
# 2023-02-27             500          1000
# 2023-01-13              30            30
# 2023-05-21             500           500
# 2023-05-06              50           100

# %%
missing_values_count = retail_sales_database_data.isnull().sum()
missing_values_count[0:10]
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
np.random.seed(0)

# %%
retail_sales_database_data.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
sns.boxplot(x=df_data['Price per Unit'])
# Out:
# <Axes: xlabel='Price per Unit'>

# %%
sns.boxplot(x=df_data['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
import numpy as np

df['Time'] = np.arange(len(df.index))

df.head(20)
# Out:
#            Customer ID  Gender  Age Product Category  Quantity  \
# Date
# 2023-11-24     CUST001    Male   34           Beauty         3
# 2023-02-27     CUST002  Female   26         Clothing         2
# 2023-01-13     CUST003    Male   50      Electronics         1
# 2023-05-21     CUST004    Male   37         Clothing         1
# 2023-05-06     CUST005    Male   30           Beauty         2
# 2023-04-25     CUST006  Female   45           Beauty         1
# 2023-03-13     CUST007    Male   46         Clothing         2
# 2023-02-22     CUST008    Male   30      Electronics         4
# 2023-12-13     CUST009    Male   63      Electronics         2
# 2023-10-07     CUST010  Female   52         Clothing         4
# 2023-02-14     CUST011    Male   23         Clothing         2
# 2023-10-30     CUST012    Male   35           Beauty         3
# 2023-08-05     CUST013    Male   22      Electronics         3
# 2023-01-17     CUST014    Male   64         Clothing         4
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns



plt.rc(
    "figure",
    autolayout=True,
    figsize=(11, 4),
    titlesize=18,
    titleweight='bold',
)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
# %config InlineBackend.figure_format = 'retina'
fig, ax = plt.subplots()
ax.plot('Time', 'Total Amount', data=df, color='0.75')
ax = sns.regplot(x='Time', y='Total Amount', data=df, ci=None, scatter_kws=dict(color='0.25'))
ax.set_title('Time Plot of Retail Sales');

# %%
from sklearn.linear_model import LinearRegression

X = df.loc[:, ['Age']]
X.dropna(inplace=True)  
y = df.loc[:, 'Quantity'] 
y, X = y.align(X, join='inner')  #

model = LinearRegression()
model.fit(X, y)

y_pred = pd.Series(model.predict(X), index=X.index)

# %%
df['Lag_1'] = df['Total Amount'].shift(1)
df.head()
# Out:
#            Customer ID  Gender  Age Product Category  Quantity  \
# Date
# 2023-11-24     CUST001    Male   34           Beauty         3
# 2023-02-27     CUST002  Female   26         Clothing         2
# 2023-01-13     CUST003    Male   50      Electronics         1
# 2023-05-21     CUST004    Male   37         Clothing         1
# 2023-05-06     CUST005    Male   30           Beauty         2
#
#             Price per Unit  Total Amount  Time   Lag_1
# Date
# 2023-11-24              50           150     0     NaN
# 2023-02-27             500          1000     1   150.0
# 2023-01-13              30            30     2  1000.0
# 2023-05-21             500           500     3    30.0
# 2023-05-06              50           100     4   500.0

# %%
from pathlib import Path
from warnings import simplefilter
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess

# %%
fig, ax = plt.subplots()
ax.plot(X['Lag_1'], y, '.', color='0.19')
ax.plot(X['Lag_1'], y_pred)
ax.set_ylabel('Total Amount')
ax.set_xlabel('Lag_1')
ax.set_title('Lag Plot of Retail Sales');

# %%
import pandas as pd
reviews = pd.read_csv(r"C:\Users\sigan\3D Objects\My Projects\Project\retail_sales_dataset.csv",index_col=0)
pd.set_option('display.max_rows', 5)

# %%
reviews.set_index("Date")
# Out:
#            Customer ID  Gender  Age Product Category  Quantity  \
# Date
# 2023-11-24     CUST001    Male   34           Beauty         3
# 2023-02-27     CUST002  Female   26         Clothing         2
# ...                ...     ...  ...              ...       ...
# 2023-12-05     CUST999  Female   36      Electronics         3
# 2023-04-12    CUST1000    Male   47      Electronics         4
#
#             Price per Unit  Total Amount
# Date
# 2023-11-24              50           150
# 2023-02-27             500          1000
# ...                    ...           ...
# 2023-12-05              50           150
# 2023-04-12              30           120
#
# [1000 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt

df_filepath = r"C:\Users\sigan\3D Objects\My Projects\Project\retail_sales_dataset.csv"
df_data = pd.read_csv(df_filepath, index_col="Date", parse_dates=True)
plt.figure(figsize=(14,6))
plt.title("Daily Retail Sales in 2023")
sns.lineplot(data=df_data)
# Out:
# <Axes: title={'center': 'Daily Retail Sales in 2023'}, xlabel='Date'>

# %%
list(df_data.columns)
# Out:
# ['Transaction ID',
#  'Customer ID',
#  'Gender',
#  'Age',
#  'Product Category',
#  'Quantity',
#  'Price per Unit',
#  'Total Amount']

# %%
plt.figure(figsize=(14,6))
plt.title("Daily Retail Sales 2023-2024")
sns.lineplot(data=df_data['Quantity'], label="Quantity")
sns.lineplot(data=df_data['Age'], label="Age")
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
df.head()
# Out:
#            Customer ID  Gender  Age Product Category  Quantity  \
# Date
# 2023-11-24     CUST001    Male   34           Beauty         3
# 2023-02-27     CUST002  Female   26         Clothing         2
# 2023-01-13     CUST003    Male   50      Electronics         1
# 2023-05-21     CUST004    Male   37         Clothing         1
# 2023-05-06     CUST005    Male   30           Beauty         2
#
#             Price per Unit  Total Amount  Time   Lag_1
# Date
# 2023-11-24              50           150     0     NaN
# 2023-02-27             500          1000     1   150.0
# 2023-01-13              30            30     2  1000.0
# 2023-05-21             500           500     3    30.0
# 2023-05-06              50           100     4   500.0

# %%
reviews.set_index("Product Category")
# Out:
#                         Date Customer ID  Gender  Age  Quantity  \
# Product Category
# Beauty            2023-11-24     CUST001    Male   34         3
# Clothing          2023-02-27     CUST002  Female   26         2
# ...                      ...         ...     ...  ...       ...
# Electronics       2023-12-05     CUST999  Female   36         3
# Electronics       2023-04-12    CUST1000    Male   47         4
#
#                   Price per Unit  Total Amount
# Product Category
# Beauty                        50           150
# Clothing                     500          1000
# ...                          ...           ...
# Electronics                   50           150
# Electronics                   30           120
#
# [1000 rows x 7 columns]

# %%
plt.figure(figsize=(10,6))
plt.title("Rate at which products are sold")
sns.barplot(x=df_data.index, y=df_data['Total Amount'])
plt.ylabel("Amount per Day")
# Out:
# Text(0, 0.5, 'Amount per Day')

# %%
sns.scatterplot(x=df_data['Quantity'], y=df_data['Total Amount'], hue=df_data['Gender'])
# Out:
# <Axes: xlabel='Quantity', ylabel='Total Amount'>

# %%
sns.lmplot(x="Quantity", y="Total Amount", hue="Product Category", data=df_data)

# %%
sns.swarmplot(x=df_data['Gender'],
              y=df_data['Total Amount'])
# Out:
# <Axes: xlabel='Gender', ylabel='Total Amount'>

# %%
df_filepath =r"C:\Users\sigan\3D Objects\My Projects\Project\retail_sales_dataset.csv"
df_data = pd.read_csv(df_filepath, index_col="Transaction ID")
df_data.head()
# Out:
#                       Date Customer ID  Gender  Age Product Category  \
# Transaction ID
# 1               2023-11-24     CUST001    Male   34           Beauty
# 2               2023-02-27     CUST002  Female   26         Clothing
# 3               2023-01-13     CUST003    Male   50      Electronics
# 4               2023-05-21     CUST004    Male   37         Clothing
# 5               2023-05-06     CUST005    Male   30           Beauty
#
#                 Quantity  Price per Unit  Total Amount
# Transaction ID
# 1                      3              50           150
# 2                      2             500          1000
# 3                      1              30            30
# 4                      1             500           500
# 5                      2              50           100

# %%
sns.kdeplot(data=df_data['Quantity'], shade=True)
# Out:
# <Axes: xlabel='Quantity', ylabel='Density'>

# %%
sns.kdeplot(data=df_data, x='Quantity', hue='Product Category', shade=True)
plt.title("Consuming Number of Quantity, by Product Category")
# Out:
# Text(0.5, 1.0, 'Consuming Number of Quantity, by Product Category')

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df_data['Quantity'], df_data['Total Amount'])
ax.set_xlabel('Quantity')
ax.set_ylabel('Total Amount')
plt.show()

# %%
df_data = df_data.loc[:,["Age","Quantity","Total Amount"]]
df_data.plot()
# Out:
# <Axes: xlabel='Date'>
